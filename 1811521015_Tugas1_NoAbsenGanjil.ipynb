# %% [markdown]
# <a href="https://colab.research.google.com/github/annisasuprima/Big-Data/blob/main/1811521015_Tugas1_NoAbsenGanjil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **A. IPYTHON MAGIC COMMANDS**

# %% [markdown]
# 1. Pasting Code Blocks: %paste and %cpaste

# %%
def donothing(x):
  return x

# %% [markdown]
# 1.a) %paste

# %%
# %paste
def donothing(x):
  return x
# Out:
# UsageError: Line magic function `%paste` not found.

# %% [markdown]
# function %paste dirancang untuk menangani kesalahan saat melalakukan penempelan kode multiline

# %%
 donothing(10)
# Out:
# 10

# %% [markdown]
# fungsi %paste berhasil dijalankan

# %% [markdown]
# 1.b) %cpaste

# %%
# %cpaste
def donothing(x):
    return x
# Out:
# UsageError: Line magic function `%cpaste` not found.

# %% [markdown]
# Perintah dengan maksud yang sama adalah% cpaste, yang membuka multiline interaktif
# prompt di mana Anda dapat menempelkan satu atau lebih potongan kode untuk dieksekusi dalam satu batch

# %%
donothing(10)
# Out:
# 10

# %% [markdown]
# 2. Running External Code: %run

# %%
#-------------------------------------
# file: myscript.py
def square(x):
 """square a number"""
 return x ** 2
for N in range(1, 4):
 print(N, "squared is", square(N))
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
# %run myscript.py
1 squared is 1
2 squared is 4
3 squared is 9
# Out:
#   File "<ipython-input-241-dd03d74e70f7>", line 2
#     1 squared is 1
#             ^
# SyntaxError: invalid syntax

# %%
square(5)
# Out:
# 25

# %% [markdown]
# Saat mulai mengembangkan kode yang lebih ekstensif, kita melakukan eksplorasi dan menyimpan kode tersebut, %run disini digunakan jika editor ingin menggunakan kode yang telah dibuat tadi tanpa membuka jendela baru.

# %% [markdown]
# 3. Timing Code Execution: %timeit

# %%
 # %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 1000 loops, best of 5: 261 µs per loop

# %% [markdown]
# % timeit, yang akan otomatis
# menentukan waktu eksekusi pernyataan Python baris tunggal yang mengikutinya.

# %%
# %%timeit
  L = []
  for n in range(1000):
    L.append(n ** 2)
# Out:
# 1000 loops, best of 5: 307 µs per loop

# %% [markdown]
# Manfaat dari% timeit adalah untuk perintah singkat, ia akan secara otomatis menjalankan beberapa langkah untuk mendapatkan hasil yang lebih baik. Untuk pernyataan multiline, menambahkan
# tanda% kedua akan mengubah ini menjadi keajaiban sel yang dapat menangani banyak baris input.

# %% [markdown]
# 4. Help on Magic Functions: ?, %magic, and %lsmagic

# %% [markdown]
#  fungsi sihir IPython memiliki dokumen, dan ini
# dokumentasi yang berguna dapat diakses dengan cara standar. Jadi, misalnya,

# %% [markdown]
# 4.a) %timeit?

# %%
# %timeit?

# %% [markdown]
# dokumentasinya akan muncul dilayar seperti gambar dibawah :![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 4.b) %magic

# %%
 # %magic

# %% [markdown]
# dokumentasinya akan muncul dilayar seperti gambar dibawah :
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 4.c) %lsmagic

# %%
 # %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# diatas merupakan dokumentasinya

# %% [markdown]
# **B. INPUT AND OUTPUT HISTORY**

# %% [markdown]
# 1. IPython’s In and Out Objects

# %%
import math

# %%
 math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %% [markdown]
# Kita telah mengimpor paket matematika bawaan, lalu menghitung sinus dan kosinus dari
# nomor 2.
#
# Tetapi masih ada lagi — IPython sebenarnya membuat beberapa variabel Python yang disebut Masuk dan Keluar yang secara otomatis diperbarui untuk mencerminkan riwayat :

# %%
print(In)
['', 'import math', 'math.sin(2)', 'math.cos(2)', 'print(In)']
# Out:
# ['', 'def donothing(x):\n... return x\n\n File "<ipython-input-20-5a66c8964687>", line 2\n ... return x', "get_ipython().magic('paste')\n>>> def donothing(x):\n... return x", "get_ipython().magic('paste')\n>>> def donothing(x):\n... return x", 'def donothing(x):\n... return x\n\n File "<ipython-input-20-5a66c8964687>", line 2\n ... return x\n\n : %paste\n>>> def donothing(x):\n... return x', 'def donothing(x):\n... return x', "get_ipython().magic('paste')\n>>> def donothing(x):\n... return x", "get_ipython().magic('paste')\ndef donothing(x):\n... return x", "get_ipython().magic('paste')\ndef donothing(x):\nreturn x", "get_ipython().magic('paste')\ndef donothing(x):\nreturn x;", 'def donothing(x):\n... return x', 'def donothing(x):\n  return x:', "get_ipython().magic('paste')\ndef donothing(x):\nreturn x :", "get_ipython().magic('paste')\ndef donothing(x):\n  return x", "get_ipython().magic('paste :')\ndef donothing(x):\n  return x", "get_ipython().magic('paste :')\ndef donothing(x):\
# ...

# %%
 Out
# Out:
# {100: 10,
#  125: 10,
#  134: 25,
#  143: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# Objek Masuk adalah daftar, yang melacak perintah secara berurutan (item pertama masuk
# list adalah placeholder sehingga In [147] bisa merujuk ke perintah ke-147) seperti dibawah:

# %%
print(In[147])
# Out:
# import math

# %% [markdown]
# Objek Out bukanlah daftar tetapi kamus yang memetakan nomor masukan ke keluarannya seperti dibawah:

# %%
print(Out[148])
# Out:
# 0.9092974268256817

# %% [markdown]
# Kita menganggap bahwa print adalah fungsi yang mengembalikan None; singkatnya, perintah apa pun
# yang mengembalikan Tidak ada tidak ditambahkan ke Keluar.
# Di mana ini bisa berguna adalah jika Anda ingin berinteraksi dengan hasil sebelumnya. Misalnya,

# %%
Out[148] ** 2 + Out[149] ** 2
# Out:
# 1.0

# %% [markdown]
# Hasilnya adalah 1,0 seperti yang kita harapkan dari identitas trigonometri yang terkenal.

# %% [markdown]
# 2. Underscore Shortcuts and Previous Outputs

# %% [markdown]
# Shell Python standar hanya berisi satu pintasan sederhana untuk mengakses sebelumnya
# keluaran; variabel _ (yaitu, garis bawah tunggal) terus diperbarui dengan keluaran sebelumnya-
# taruh; ini berfungsi di IPython juga:

# %%
print(_)
# Out:
# 1.0

# %% [markdown]
# Kita dapat menggunakan garis bawah ganda untuk mengakses file
# keluaran kedua hingga terakhir, dan garis bawah tiga kali lipat untuk mengakses keluaran ketiga hingga terakhir (skip-ping perintah apa pun tanpa output):

# %%
print(__)
# Out:
# ['', 'import math', 'math.sin(2)', 'math.cos(2)', 'print(In)']

# %%
print(___)
# Out:
# -0.4161468365471424

# %% [markdown]
# IPython berhenti di situ: lebih dari tiga garis bawah mulai menjadi agak sulit dihitung,
# dan pada saat itu lebih mudah untuk merujuk ke keluaran dengan nomor baris.

# %%
Out[148]
# Out:
# 0.9092974268256817

# %%
_148
# Out:
# 0.9092974268256817

# %% [markdown]
# 3. Suppressing Output

# %% [markdown]
# Cara termudah untuk menekan keluaran dari sebuah perintah adalah dengan menambahkan titik koma

# %%
math.sin(2) + math.cos(2);

# %% [markdown]
# Note :hasilnya dihitung secara diam-diam, dan hasilnya tidak ditampilkan di
# layar atau disimpan dalam out dictionary:

# %%
14 in Out
# Out:
# False

# %% [markdown]
# 4. Related Magic Commands

# %% [markdown]
# Untuk mengakses sekumpulan input sebelumnya sekaligus, Magic Command %history
# sangat membantu. Berikut adalah cara mencetak empat masukan pertama:

# %%
# %history -n 147-150
# Out:
#  147: import math
#  148:  math.sin(2)
#  149: math.cos(2)
#  150:
# print(In)
# ['', 'import math', 'math.sin(2)', 'math.cos(2)', 'print(In)']

# %% [markdown]
# **C. IPYTHON AND SHELL COMMANDS**

# %% [markdown]
# **1. Shell Commands in IPython**
#
# Kita dapat menggunakan perintah apa pun yang berfungsi pada baris perintah di IPython dengan mengawalnya
# dengan ! karakter. Misalnya, perintah ls, pwd, dan echo dapat dijalankan sebagai
# berikut:

# %%
# ls = list working directory contents
# !ls
# Out:
# sample_data

# %%
 # pwd = print working directory
 # !pwd
# Out:
# /content

# %%
 # echo is like Python's print function
 # !echo "printing from the shell"
# Out:
# printing from the shell

# %% [markdown]
# **2. Passing Values to and from the Shell**
#
# Perintah shell tidak hanya dapat dipanggil dari IPython, tetapi juga dapat dibuat untuk
# bertindak dengan namespace IPython. Misalnya, Kita dapat menyimpan output dari shell apa pun
# perintah ke daftar Python menggunakan operator penugasan:

# %%
contents = !ls

# %%
 print(contents)
# Out:
# ['sample_data']

# %%
directory = !pwd

# %%
 print(directory)
# Out:
# ['/content']

# %%
 type(directory)
# Out:
# IPython.utils.text.SList

# %% [markdown]
# metode grep dan field serta properti s, n, dan p yang memungkinkan untuk mencari,
# menyaring, dan menampilkan hasilnya dengan cara yang nyaman. Komunikasi direction-passing Python ke dalam shell — adalah melalui sintaks {varname}:

# %%
message = "hello from Python"

# %%
 # !echo {message}
# Out:
# hello from Python

# %% [markdown]
# **D. Shell-Related Magic Commands**

# %% [markdown]
# Kita tidak dapat menggunakan! Cd untuk menavigasi sistem file:

# %%
 # !pwd
# Out:
# /content

# %%
 # !cd ..

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# Alasannya adalah karena perintah shell di notebook dijalankan di sub-shell sementara. Jika kita ingin mengubah direktori kerja dengan cara yang lebih tahan lama, kita bisa
# gunakan magic command %cd:

# %%
 # %cd ..
# Out:
# /

# %%
 cd content
# Out:
# /content

# %% [markdown]
# Selain% cd, magic command seperti shell lainnya yang tersedia adalah %cat,%cp,%env,%ls,%man,
# %mkdir,%more,%mv,%pwd,%rm, dan %rmdir, yang mana saja dapat digunakan tanpa tanda % jika automagic aktif. sehingga hampir bisa memperlakukan IPython eolah-olah itu adalah shell biasa:

# %%
mkdir tmps

# %% [markdown]
# mkdir= make new directory

# %%
 ls
# Out:
# sample_data/  tmp/  tmps/

# %%
cp myproject.txt tmp/
# Out:
# cp: cannot stat 'myproject.txt': No such file or directory

# %%
 ls tmps

# %%
 rm -r tmps

# %% [markdown]
# Akses ke shell ini dari dalam jendela terminal yang sama dengan sesi Python, berarti bahwa ada lebih sedikit perpindahan bolak-balik antara interpreter dan shell saat menulis kode Python.
